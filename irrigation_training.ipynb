# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import os
from irrigation_environment import IrrigationEnv

def animate_training_progression(all_grids, log_interval=1000, save_path="training_progression.gif", label="Training"):    
    all_frames = []
    episode_labels = []    
    for i, episode_frames in enumerate(all_grids):
        episode_num = (i + 1) * log_interval
        for frame in episode_frames:
            all_frames.append(frame)
            episode_labels.append(f"{label} Episode: {episode_num}")
    if len(all_frames) == 0:
        print("No frames found to animate.")
        return
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.axis('off')
    im = ax.imshow(all_frames[0])
    title = ax.set_title(episode_labels[0])
    def update(frame_idx):
        im.set_array(all_frames[frame_idx])
        title.set_text(episode_labels[frame_idx])
        return [im, title]
    print(f"Generating animation with {len(all_frames)} frames...")
    ani = animation.FuncAnimation(
        fig, update, frames=len(all_frames), interval=50, blit=False
    )
    
    try:
        print(f"Saving to {save_path} (this might take a minute)...")
        ani.save(save_path, writer='pillow', fps=15)
        print(f"Success! Saved to {save_path}")
    except Exception as e:
        print(f"Error saving animation: {e}")
    finally:
        plt.close(fig)

def train_agent():
    # --- Hyperparameters ---
    total_episodes = 50000        
    max_steps = 600         
    learning_rate = 0.15          
    discount_rate = 0.99         
    epsilon = 1.0
    max_epsilon = 1.0
    min_epsilon = 0.01
    decay_rate = 0.0005           
    log_interval = 500   
    log_animation = 10000     
    
    env = IrrigationEnv()
    
    action_size = env.action_space.n
    state_size = env.observation_space.n
    qtable = np.zeros((state_size, action_size))
    grids = [] 
    log_filename = "training_log.csv"
    
    with open(log_filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Episode", "Total Reward", "Steps", "Epsilon"])

    print(f"Starting Training: Total - {total_episodes}")
    
    for episode in range(total_episodes):
        state, info = env.reset()
        total_rewards = 0
        terminated = False
        is_logging_episode = (episode + 1) % log_interval == 0
        is_animating = (episode + 1) % log_animation == 0
        episode_grids = []

        for step in range(max_steps):
            action_mask = info["action_mask"]  
            exp_exp_tradeoff = np.random.uniform(0, 1)

            if exp_exp_tradeoff > epsilon:
                # Exploitation
                masked_q_values = qtable[state, :].copy()
                masked_q_values[action_mask == 0] = -np.inf                 
                max_q = np.max(masked_q_values)
                best_actions = np.flatnonzero(masked_q_values == max_q)
                action = np.random.choice(best_actions)
            else:
                # Exploration
                valid_actions = np.flatnonzero(action_mask == 1)
                if len(valid_actions) > 0:
                    action = np.random.choice(valid_actions)
                else:
                    action = env.action_space.sample() 
            
            new_state, reward, terminated, _, info = env.step(action)
            
            next_action_mask = info["action_mask"]
            masked_next_q = qtable[new_state, :].copy()
            masked_next_q[next_action_mask == 0] = -np.inf
            
            target_q = reward + discount_rate * np.max(masked_next_q)
            qtable[state, action] += learning_rate * (target_q - qtable[state, action])
            
            total_rewards += reward
            state = new_state
            
            if is_animating:
                current_grid = env.render()
                episode_grids.append(current_grid)
            if terminated:
                break
                
        epsilon = min_epsilon + (max_epsilon - min_epsilon) * np.exp(-decay_rate * episode)
        
        if is_logging_episode:
            print(f"Episode {episode + 1}: Reward: {total_rewards:.1f}, Epsilon: {epsilon:.4f}")
            grids.append(episode_grids)
            with open(log_filename, mode="a", newline="") as file:
                writer = csv.writer(file)
                writer.writerow([episode + 1, total_rewards, step, epsilon])
    
    print("Training Finished.")
    return (qtable, grids, log_interval, log_animation)

def validate_agent(qtable, num_episodes=5):
    print("\n--- Starting Validation ---")
    env = IrrigationEnv()
    max_steps = 400
    total_test_rewards = []
    validation_grids = []

    for episode in range(num_episodes):
        state, info = env.reset()
        episode_reward = 0
        terminated = False
        episode_grids = []

        for step in range(max_steps):
            action_mask = info["action_mask"]
            masked_q_values = qtable[state, :].copy()
            masked_q_values[action_mask == 0] = -np.inf
            max_q = np.max(masked_q_values)
            best_actions = np.flatnonzero(masked_q_values == max_q)
            action = np.random.choice(best_actions)
            
            new_state, reward, terminated, _, info = env.step(action)
            episode_reward += reward
            state = new_state
            
            curr_grid = env.render()
            episode_grids.append(curr_grid)
            if terminated:
                break
                
        total_test_rewards.append(episode_reward)
        print(f"Validation Episode {episode + 1}: Total Reward = {episode_reward:.1f}")
        validation_grids.append(episode_grids)
        
    avg_reward = np.mean(total_test_rewards)
    
    return (avg_reward, validation_grids)


qtable, train_grids, log_int, log_animation = train_agent()
animate_training_progression(train_grids, log_interval=log_animation, save_path=f"test-run.gif", label="Test")

validation_total = 0
validation_iteration = 10
for i in range(validation_iteration):
    avg_reward, val_grids = validate_agent(qtable, num_episodes=5)
    animate_training_progression(val_grids, log_interval=1, save_path=f"validation_run-{i}.gif", label="Validation")
    print(f"\nValidation #{i} Finished. Average Reward: {avg_reward:.1f}")
    validation_total += avg_reward
    
validation_avg = validation_total / validation_iteration
# Out:
# Starting Training: Total - 50000
# Episode 500: Reward: -1787.5, Epsilon: 0.7814
# Episode 1000: Reward: 642.1, Epsilon: 0.6108
# Episode 1500: Reward: -1340.5, Epsilon: 0.4779
# Episode 2000: Reward: -1388.3, Epsilon: 0.3744
# Episode 2500: Reward: -1872.7, Epsilon: 0.2938
# Episode 3000: Reward: -1547.5, Epsilon: 0.2310
# Episode 3500: Reward: -1338.7, Epsilon: 0.1821
# Episode 4000: Reward: -1367.2, Epsilon: 0.1440
# Episode 4500: Reward: 203.0, Epsilon: 0.1144
# Episode 5000: Reward: 8.2, Epsilon: 0.0913
# Episode 5500: Reward: -1164.8, Epsilon: 0.0733
# Episode 6000: Reward: -551.3, Epsilon: 0.0593
# Episode 6500: Reward: -962.6, Epsilon: 0.0484
# Episode 7000: Reward: 816.4, Epsilon: 0.0399
# Episode 7500: Reward: 871.8, Epsilon: 0.0333
# Episode 8000: Reward: 370.5, Epsilon: 0.0281
# Episode 8500: Reward: 907.1, Epsilon: 0.0241
# Episode 9000: Reward: -1686.5, Epsilon: 0.0210
# Episode 9500: Reward: 500.6, Epsilon: 0.0186
# Episode 10000: Reward: 997.2, Epsilon: 0.0167
# Episode 10500: Reward: -293.0, Epsilon: 0.0152
# Episode 11000: Reward: 764.2, Epsilon: 0.0140
# Episode 11500: Reward: 259.1, Epsilon: 0.0132
# Episode 12000: Reward: -693.1, Epsilon: 0.0125
# Episode 12500: Reward: -1009.9, Epsilon: 0.0119
# Episode 13000: Reward: -491.6, Epsilon: 0.0115
# Episode 13500: Reward: 981.8, Epsilon: 0.0112
# Episode 14000: Reward: 1036.3, Epsilon: 0.0109
# Episode 14500: Reward: 1021.2, Epsilon: 0.0107
# Episode 15000: Reward: 843.1, Epsilon: 0.0105
# Episode 15500: Reward: 927.5, Epsilon: 0.0104
# Episode 16000: Reward: 1087.7, Epsilon: 0.0103
# Episode 16500: Reward: 973.2, Epsilon: 0.0103
# Episode 17000: Reward: 976.8, Epsilon: 0.0102
# Episode 17500: Reward: 1021.2, Epsilon: 0.0102
# Episode 18000: Reward: 1056.4, Epsilon: 0.0101
# Episode 18500: Reward: -1822.0, Epsilon: 0.0101
# Episode 19000: Reward: 946.6, Epsilon: 0.0101
# Episode 19500: Reward: 48.6, Epsilon: 0.0101
# Episode 20000: Reward: 813.5, Epsilon: 0.0100
# Episode 20500: Reward: -1231.7, Epsilon: 0.0100
# Episode 21000: Reward: -358.9, Epsilon: 0.0100
# Episode 21500: Reward: -541.2, Epsilon: 0.0100
# Episode 22000: Reward: 417.3, Epsilon: 0.0100
# Episode 22500: Reward: 856.9, Epsilon: 0.0100
# Episode 23000: Reward: 1021.6, Epsilon: 0.0100
# Episode 23500: Reward: 1055.8, Epsilon: 0.0100
# Episode 24000: Reward: 924.3, Epsilon: 0.0100
# Episode 24500: Reward: 540.4, Epsilon: 0.0100
# Episode 25000: Reward: 1034.5, Epsilon: 0.0100
# Episode 25500: Reward: -2730.1, Epsilon: 0.0100
# Episode 26000: Reward: 1051.2, Epsilon: 0.0100
# Episode 26500: Reward: 1055.5, Epsilon: 0.0100
# Episode 27000: Reward: -753.6, Epsilon: 0.0100
# Episode 27500: Reward: 390.9, Epsilon: 0.0100
# Episode 28000: Reward: -308.9, Epsilon: 0.0100
# Episode 28500: Reward: -1171.2, Epsilon: 0.0100
# Episode 29000: Reward: -946.5, Epsilon: 0.0100
# Episode 29500: Reward: -2167.5, Epsilon: 0.0100
# Episode 30000: Reward: 735.4, Epsilon: 0.0100
# Episode 30500: Reward: 883.3, Epsilon: 0.0100
# Episode 31000: Reward: 1028.2, Epsilon: 0.0100
# Episode 31500: Reward: 1005.9, Epsilon: 0.0100
# Episode 32000: Reward: 1022.6, Epsilon: 0.0100
# Episode 32500: Reward: -630.0, Epsilon: 0.0100
# Episode 33000: Reward: 909.2, Epsilon: 0.0100
# Episode 33500: Reward: -1124.4, Epsilon: 0.0100
# Episode 34000: Reward: -901.4, Epsilon: 0.0100
# Episode 34500: Reward: -300.1, Epsilon: 0.0100
# Episode 35000: Reward: -306.2, Epsilon: 0.0100
# Episode 35500: Reward: -237.9, Epsilon: 0.0100
# Episode 36000: Reward: 1064.4, Epsilon: 0.0100
# Episode 36500: Reward: 1012.5, Epsilon: 0.0100
# Episode 37000: Reward: 1012.1, Epsilon: 0.0100
# Episode 37500: Reward: -1745.0, Epsilon: 0.0100
# Episode 38000: Reward: 900.7, Epsilon: 0.0100
# Episode 38500: Reward: 1049.0, Epsilon: 0.0100
# Episode 39000: Reward: 1070.4, Epsilon: 0.0100
# Episode 39500: Reward: 1027.2, Epsilon: 0.0100
# Episode 40000: Reward: 860.9, Epsilon: 0.0100
# Episode 40500: Reward: 252.5, Epsilon: 0.0100
# Episode 41000: Reward: 567.8, Epsilon: 0.0100
# Episode 41500: Reward: -1132.5, Epsilon: 0.0100
# Episode 42000: Reward: -1079.1, Epsilon: 0.0100
# Episode 42500: Reward: 696.0, Epsilon: 0.0100
# Episode 43000: Reward: -634.1, Epsilon: 0.0100
# Episode 43500: Reward: -211.7, Epsilon: 0.0100
# Episode 44000: Reward: -104.8, Epsilon: 0.0100
# Episode 44500: Reward: 1021.2, Epsilon: 0.0100
# Episode 45000: Reward: 987.7, Epsilon: 0.0100
# Episode 45500: Reward: 749.6, Epsilon: 0.0100
# Episode 46000: Reward: 678.8, Epsilon: 0.0100
# Episode 46500: Reward: -949.8, Epsilon: 0.0100
# Episode 47000: Reward: -133.8, Epsilon: 0.0100
# Episode 47500: Reward: 267.2, Epsilon: 0.0100
# Episode 48000: Reward: -2890.0, Epsilon: 0.0100
# Episode 48500: Reward: 726.7, Epsilon: 0.0100
# Episode 49000: Reward: 1022.8, Epsilon: 0.0100
# Episode 49500: Reward: 1034.6, Epsilon: 0.0100
# Episode 50000: Reward: 1032.3, Epsilon: 0.0100
# Training Finished.
# Generating animation with 769 frames...
# Saving to test-run.gif (this might take a minute)...
# Success! Saved to test-run.gif
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = 1012.1
# Validation Episode 2: Total Reward = 1024.9
# Validation Episode 3: Total Reward = 1032.0
# Validation Episode 4: Total Reward = 1062.8
# Validation Episode 5: Total Reward = -1816.0
# Generating animation with 542 frames...
# Saving to validation_run-0.gif (this might take a minute)...
# Success! Saved to validation_run-0.gif
#
# Validation #0 Finished. Average Reward: 463.2
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = -1831.0
# Validation Episode 2: Total Reward = 1011.9
# Validation Episode 3: Total Reward = 990.9
# Validation Episode 4: Total Reward = 1015.0
# Validation Episode 5: Total Reward = 1040.8
# Generating animation with 534 frames...
# Saving to validation_run-1.gif (this might take a minute)...
# Success! Saved to validation_run-1.gif
#
# Validation #1 Finished. Average Reward: 445.5
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = 1023.4
# Validation Episode 2: Total Reward = 1025.8
# Validation Episode 3: Total Reward = -1857.0
# Validation Episode 4: Total Reward = 998.3
# Validation Episode 5: Total Reward = 1050.7
# Generating animation with 538 frames...
# Saving to validation_run-2.gif (this might take a minute)...
# Success! Saved to validation_run-2.gif
#
# Validation #2 Finished. Average Reward: 448.2
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = 1034.9
# Validation Episode 2: Total Reward = 1034.6
# Validation Episode 3: Total Reward = 1010.5
# Validation Episode 4: Total Reward = 1046.3
# Validation Episode 5: Total Reward = 1016.1
# Generating animation with 156 frames...
# Saving to validation_run-3.gif (this might take a minute)...
# Success! Saved to validation_run-3.gif
#
# Validation #3 Finished. Average Reward: 1028.5
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = -856.0
# Validation Episode 2: Total Reward = 1031.2
# Validation Episode 3: Total Reward = 929.5
# Validation Episode 4: Total Reward = 1083.0
# Validation Episode 5: Total Reward = 996.2
# Generating animation with 561 frames...
# Saving to validation_run-4.gif (this might take a minute)...
# Success! Saved to validation_run-4.gif
#
# Validation #4 Finished. Average Reward: 636.8
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = 996.1
# Validation Episode 2: Total Reward = -910.0
# Validation Episode 3: Total Reward = 1039.6
# Validation Episode 4: Total Reward = 996.6
# Validation Episode 5: Total Reward = 1018.5
# Generating animation with 532 frames...
# Saving to validation_run-5.gif (this might take a minute)...
# Success! Saved to validation_run-5.gif
#
# Validation #5 Finished. Average Reward: 628.2
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = 1021.9
# Validation Episode 2: Total Reward = 1010.3
# Validation Episode 3: Total Reward = 979.3
# Validation Episode 4: Total Reward = 1038.1
# Validation Episode 5: Total Reward = 1027.9
# Generating animation with 165 frames...
# Saving to validation_run-6.gif (this might take a minute)...
# Success! Saved to validation_run-6.gif
#
# Validation #6 Finished. Average Reward: 1015.5
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = 1043.9
# Validation Episode 2: Total Reward = 1049.1
# Validation Episode 3: Total Reward = 1033.0
# Validation Episode 4: Total Reward = -1851.0
# Validation Episode 5: Total Reward = 977.7
# Generating animation with 533 frames...
# Saving to validation_run-7.gif (this might take a minute)...
# Success! Saved to validation_run-7.gif
#
# Validation #7 Finished. Average Reward: 450.5
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = 1043.3
# Validation Episode 2: Total Reward = -1850.0
# Validation Episode 3: Total Reward = -859.0
# Validation Episode 4: Total Reward = 1062.3
# Validation Episode 5: Total Reward = 1004.1
# Generating animation with 903 frames...
# Saving to validation_run-8.gif (this might take a minute)...
# Success! Saved to validation_run-8.gif
#
# Validation #8 Finished. Average Reward: 80.1
#
# --- Starting Validation ---
# Validation Episode 1: Total Reward = 954.5
# Validation Episode 2: Total Reward = -1819.0
# Validation Episode 3: Total Reward = 1043.5
# Validation Episode 4: Total Reward = 1066.0
# Validation Episode 5: Total Reward = 1000.8
# Generating animation with 532 frames...
# Saving to validation_run-9.gif (this might take a minute)...
# Success! Saved to validation_run-9.gif
#
# Validation #9 Finished. Average Reward: 449.2
